# %% [markdown]
# # X-AI Module Assignment: Predicting and explaining genetic disorders
#
# Genetic disorder is a health condition that is usually caused by mutations in DNA or changes in the structure of chromosomes. Several commonly-known diseases are related to hereditary gene mutations. Genetic testing thus aids patients in making crucial decisions in the prevention, treatment or early detection of hereditray disorders.
#
# In this assignment, you will be coming up with a genetic disorder prediction model based on the children's medical information. In addition, as medicine is a safty-critical domain, it is important to provide insights how your model is working. Therefore we will apply post-hoc blackbox explaination methods such as LIME and Anchor.
#
# data source: https://www.kaggle.com/aibuzz/predict-the-genetic-disorders-datasetof-genomes?select=train_genetic_disorders.csv

# %% [markdown]
# KATE expects your code to define variables with specific names that correspond to certain things we are interested in.
#
# KATE will run your notebook from top to bottom and check the latest value of those variables, so make sure you don't overwrite them.
#
# * Remember to uncomment the line assigning the variable to your answer and don't change the variable or function names.
# * Use copies of the original or previous DataFrames to make sure you do not overwrite them by mistake.
#
# You will find instructions below about how to define each variable.
#
# Once you're happy with your code, upload your notebook to KATE to check your feedback.

# %% [markdown]
# KATE expects your code to define variables with specific names that correspond to certain things we are interested in.
#
# KATE will run your notebook from top to bottom and check the latest value of those variables, so make sure you don't overwrite them.
#
# * Remember to uncomment the line assigning the variable to your answer and don't change the variable or function names.
# * Use copies of the original or previous DataFrames to make sure you do not overwrite them by mistake.
#
# You will find instructions below about how to define each variable.
#
# Once you're happy with your code, upload your notebook to KATE to check your feedback.

# %% [markdown]
# ---
# ### Feature description and data type
#
# |     Column Name     | Column description  | Data type|
# |:-------------------:|:-------:|:---:|
# |Patient Id| Unique Identification number of patient | String |
# |Patient Age | Represents the age of a patient | Numerical |
# |Genes in mother's side| Presents a gene defect in a patient's mother | Binary |
# |Inherited from father | Represents a gene defect in a patient's father | Binary |
# |Maternal gene | Represents a gene defect in the patient's maternal side of family | Binary |
# |Paternal gene | Represents a gene defect in the patient's paternal side of family | Binary |
# |Blood cell count (mcL) | Represents the blood cell count of a patient | Numerical |
# |Patient First Name | Represents a patient's first name | String |
# |Family Name| Represents a patient's family name or surname | String |
# |Father's Name | Represents a patient's father's name | String |
# |Mother's Age | Represents a patient's mother's age | Numerical |
# |Father's Age | Represents a patient's father's age | Numerical |
# |Institute Name | Represents the medical institute where a patient was born | String |
# |Location of Institute | Represents the location of the medical institute | String |
# |Status| Represents whether a patient is deceased | Binary |
# |Respiratory Rate (breaths/min) | Represents a patient's respiratory breathing rate | Categorical |
# |Heart Rate (rates/min) | Represents a patient's heart rate | Categorical |
# |Test 1 |Represents masked test that were conducted on patient | Binary |
# |Test 2 |Represents masked test that were conducted on patient | Binary |
# |Test 3 |Represents masked test that were conducted on patient | Binary |
# |Test 4 |Represents masked test that were conducted on patient | Binary |
# |Test 5 |Represents masked test that were conducted on patient | Binary |
# |Parental consent |Represents whether a patient's parents approved the treatment plan | Binary |
# |Follow-up | Represents a patient's level of risk |  Binary |
# |Gender | Represents a patient's gender | Categorical |
# |Birth asphyxia | Represents whether a patient suffered from birth asphyxia | Categorical |
# |Autopsy shows birth defect (if applicable)|Represents whether a patient's autopsy showed any birth defects | Categorical |
# |Place of birth | Represents whether a patient was born in a medical institute or home | Categorical |
# |Folic acid details (periconceptional)| Represents the periconceptional folic acid supplementation details of a patient | Binary |
# |H/O serious maternal illness| Represents an unexpected outcome of labor and delivery that resulted in significant short or long-term consequences to a patient's mother | Binary |
# |H/O radiation exposure (x-ray)|Represents whether a patient has any radiation exposure history| Categorical |
# |H/O substance abuse| Represents whether a parent has a history of drug addiction | Categorical |
# |Assisted conception IVF/ART | Represents the type of treatment used for infertility | Binary |
# |History of anomalies in previous pregnancies| Represents whether the mother had any anomalies in her previous pregnancies| Binary |
# |No. of previous abortion | Represents the numbedr of abortions that a mother had | Numerical |
# |Birth defects | Represents whether a patient has birth | Categorical |
# |White Blood cell count (thousand per microliter) | Represents a patient's white blood cell count | Numerical |
# |Blood test result | Represents a patient's blood test results | Categorical |
# |Symptom 1 | Represents masked different types of symptoms that a patient had | Binary |
# |Symptom 2 | Represents masked different types of symptoms that a patient had | Binary |
# |Symptom 3 | Represents masked different types of symptoms that a patient had | Binary |
# |Symptom 4 | Represents masked different types of symptoms that a patient had | Binary |
# |Symptom 5 | Represents masked different types of symptoms that a patient had | Binary |
# |Genetic Disorder | Represents the genetic disorder that a patient has | Categorical |
# |Disorder Subclass | Represents the subclass of the disorder | Categorical |

# %% [markdown]
# -----
# ### Setup
#
# We will import `numpy` and `pandas` for all data manipulation task. `Matplotlib` and `seaborn` will be used to for exploratory data analysis. `sklearn` will be used to train our classification model and we will use `lime` and `alibi` to run the algorithm *LIME* and *Anchor* respectively.

# %%
# Basic packages
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# Preprocessing and Modelling
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Anchor
from alibi.explainers import AnchorTabular

# LIME
import lime
from lime.lime_tabular import LimeTabularExplainer

# %%
# Load Data
df0 = pd.read_csv("data/genetic_disorders.csv")

print("Number of data: %.i \nNumber of features: %.i " %df0.shape)

# %% [markdown]
# ### Part 1: Data Preprocessing
#
# ---
# **Q1. Drop the NaNs**
#
# There are a lot of missing values in this dataset. Instead of imputing the missing values (i.e replace it with mean/median values), we will drop all entries containing NANs using the `.dropna()` method. This is done to avoid inducing any uncessary biases to our modelling.
#
# - Stage 1: print the number of entries that contain nans.
# - Stage 2: Drop all erntries containing NANs using the `.dropna()` method. Assign the new dataframe as `df1`.

# %%
# Your code here...
# df1 = ...

# %%
# Setting up our labels. We will not be using `disorder_subclass` in our prediction.
genetic_disorder = df1.loc[:, "Genetic Disorder"]
disorder_subclass = df1.loc[:, "Disorder Subclass"]

df1 = df1.iloc[:, :-2]

# %% [markdown]
# ---
# **Q1.5 Exploratory Data Analysis**
#
# When we run a classification model, it is important to check whether there is a strong imbalance in the output classes.
#
#
# - use the method `.value_counts()` to check whether there is class imbalances.

# %% [markdown]
# ---
# **Q2. Removing non-informative features**
#
# Drop the following features:
#
# - `Patient First Name`
# - `Family Name`
# - `Father's name`
# - `Institute Name`
# - `Location of Institute`
# - `Status`
#
# Name the resulting trimmed dataset as `df2`. Also set the feature `Patient Id` as index of the df and then drop it.

# %%
# Your code here...
# df2 = ...

# %% [markdown]
# ---
# **Q3. One-hot encode categorical features**
#
# Our data is not at its cleanest state. Let's apply one hot encoding to transform the categorical features. Watch out, there are binary features such as `Genes in mother\'s side` encoded as strings ('Yes'/'No') as well.
#
# - Stage 1: Loop through the features and use the function `type` to determine the type of that feature. Create a list of feature types and subset the data based on whether the feature is of type `str`. Name it `categorical_frame`.
# - Stage 2: Similarly, for type not equal to `str`, we set up a sub dataframe calling it `numerical_frame`.
# - Stage 3: Set up the encoder using `OneHotEncoder` function. Name it `encoder`. Apply `encoder` to the categorical data. Use `encoder.get_feature_names_out(categorical_frame.columns)` to name the new dataframe's column.
# - Stage 4: Combine with `numerical_features` and rearrange the columns according to ascending alphabetical order.
#
# Call the resulting dataframe `df3`.

# %%
# Your code here...
# categorical_frame = ...
# numerical_frame = ...
# encoder = ...
# df3 = ...

# %% [markdown]
# ### Part 2: Machine Learning Model
# ---
# **Q.4 Fit a predictive model to predict the type of genetic disorder**
#
# Here we will fit a `Random Forest Classifier` to model the genetic disorder given the patient's medical information.
#
# - Stage 1: Do a train-test split using the function `train_test_split()`. Set the `test_size` as `0.3` and use random seed `1234` for reproducibility.
# - Stage 2: Instantiate a Random Forest Classifier using `RandomForestClassifier` with `200` trees. Recall that our output classes are imbalanced, therefore we should set the attribute `class_weight` to `"balanced"`. Assign the model to the variable `rf`. Run the model.
# - Stage 3: Use metrics `accuracy_score()` and `confusion_matrix()` to examine the model's predictive performance on our test set.
# - Stage 4: Extract the feature importances from the model object `rf`. Return the top five important feature as a list. Call it `rf_top_five_imp_features_ls`.

# %%
X_train, X_test, y_train, y_test = train_test_split(np.array(df3),
                                                    genetic_disorder,
                                                    test_size=0.3,
                                                    random_state=1234
                                                   )
# Your code here ...
# rf = ...
# rf_top_five_imp_features_ls = ...

# %% [markdown]
# ---
# **Q.5 Random Forest Importance Score**
#
# Which of the following most accurately describe the feature importance method used in `RandomForestClassifier()`.
#
# 1. It is a global explanation method.
# 2. It is a local explanation method.
# 3. It computes the average frequency of a feature appearing as splitting criterion in the forest.
# 4. It computes the average deduction in gini importance brought by the feature.
#
# Multiple choice:
# - A: 1,3
# - B: 1,4
# - C: 2,3
# - D: 2,4
#
# Assign your solution to the variable `q5`, for example `q5 = "A"`.

# %%
# Your code here ...
# Q5 = ...

# %% [markdown]
# ---
# ### Part 3.1: Explaining our model using Anchor.
#
# **Q6. Set up Anchor on our Random Forest model and decipher patient PID0x74ab's prediction.**
#
# Part 1: Initialise anchor:
# - Stage 1: Set up the Random Forest prediction model.
# - Stage 2: Instantiate the anchor module using `AnchorTabular()` with the random forest prediction model as predictor. Call the object `anchor_exp_obj`.
# - Stage 3: Fit discretizer to train data to bin numerical features into ordered bins and compute statistics for numerical features using the `.fit()` method. Set the discretization parameter as `disc_perc = [20, 40, 60, 80]`.
#
# Part 2: Run Anchor on Patient 'PID0x74ab':
# - Stage 4: Explain the prediction of patient 'PID0x74ab' using `anchor_exp_obj.explain()`. Set the threshold parameter to be `0.9`. Save this as the variable `anchor_explanation`.

# %%
# Your code here ...
# anchor_exp_obj = ...
# anchor_explanation = ...

# %% [markdown]
# ---
#
# **Q.7 Interpreting the explanation from Anchor**
#
#
# Examine the interpretation by checking the attributes `anchor`, `precision` and `coverage`. Answer the following question regarding to the explanation of patient PID0x74ab's prediction.
#
# - 1. Predictions on observations where the anchor holds will be the same as the prediction on the patient 'PID0x74ab' at least [A] of the time. What is [A]?
# - 2. [B] amount of patients share the same anchor constraint as patient 'PID0x74ab'. What is [B]?
# - 3. 'Symptom 5 == 1.0' is part of the anchoring rule. "Yes" or "No"?
#
# Return your solution as a list, for example: `q7 = [0.1, 0.1, "Yes"]`.
#
# Please note that anchor_explanation from Q6 will need to be implemented before attempting Q7.

# %%
# Your code here ...
# q7 = ...

# %% [markdown]
# ---
#
# ### Part 3.2: Explaining our model using LIME.
#
# **Q8. Set up *LIME* on our Random Forest model and decipher patient PID0x74ab's prediction**
#
# - Stage 1: Instantiate the lime explainer using `LimeTabularExplainer()` function. Use the whole `df3` as `training_data` and `df3.columns` as `feature_names`. Call the object `lime_exp_obj`.
# - Stage 2: Obtain explanation for patient 'PID0x74ab' using `.explain_instance()`. Use `rf.predict_proba()` as our prediction function. Set `top_labels=1` as we want to produce explanations for the label with highest prediction probabilities. Call the resulting object `lime_explanation`.

# %%
# Your code here ...
# lime_exp_obj = ...
# lime_explanation = ...

# %% [markdown]
# **Q9. Interperet the explanation from LIME.**
#
# Using visualisation methods such as `show_in_notebook()`, `as_list()` and `as_pyplot_fiture()` on the `lime_explanation` object, answer the following question regarding to the explanation of patient PID0x74ab's prediction.
#
# - Which symptom when present (i.e = 1), gives the strongest negative momentum to the prediction of class 'Mitochondrial genetic inheritance disorders'?
# - Which symptom when absent (i.e = 0), gives the strongest positive momentum to the prediction of class "Single-gene inheritance diseases" ?
# - Which symptom when present (i.e = 1), gives the least positive momentum to the prediction of class "Multifactorial genetic inheritance diseases" ?
#
# return your solution as a list of floats, i.e `q9 = [1.0, 1.0, 1.0]`.

# %%
# Your code here ...
# q9 = ...

# %% [markdown]
# ---
# **Q10. Comparing LIME and Anchor**
#
# Which of the following descriptions most accurately describe *LIME* and *Anchor* ?
#
# - A. *LIME* is a local explanation method while *Anchor* is a global explanation method.
# - B. *LIME* learns a local best fit line while *Anchor* learns a local best fit region.
# - C. *Anchor* searches using the beam search algorithm therefore it can only be applied to tree-based machine learning algorithm while *LIME* is model agnostic.
#
# Return the solution as string, i.e `q10 = "A"`.

# %%
# Your code here ...
# q10 = ...
